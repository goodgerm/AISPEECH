# %%
# !pip install librosa

# %%
import librosa
y, sr = librosa.load('/content/Ai.mp3')
librosa.display.waveshow(y)

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns

from glob import glob

import librosa
import librosa.display
import IPython.display as ipd

from itertools import cycle

sns.set_theme(style="white", palette=None)
color_pal = plt.rcParams["axes.prop_cycle"].by_key()["color"]

# %% [markdown]
# 2.

# %%
duration = len(y) / sr
print(f"Duration of the audio: {duration:.2f} seconds")
print(f"Magnitude range: {y.min()} to {y.max()}")
# Out:
# Duration of the audio: 4.30 seconds
# Magnitude range: -0.307728111743927 to 0.4750324487686157

# %% [markdown]
# 3.

# %%
y, sr = librosa.load('/content/Ai.mp3' , offset=0.0, duration=1.0)
y
# Out:
# array([0.        , 0.        , 0.        , ..., 0.20997831, 0.20424864,
#        0.20739496], dtype=float32)

# %%
from IPython.display import Audio, display
audio1 = Audio(y, rate=sr)
display(audio1)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# 4.

# %%
y, sr = librosa.load('/content/Ai.mp3' , offset=1.0, duration=1.0)
audio2 = Audio(y, rate=sr)
display(audio2)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
y, sr = librosa.load('/content/Ai.mp3' , offset=2.0, duration=3.0)
audio2 = Audio(y, rate=sr)
display(audio2)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
